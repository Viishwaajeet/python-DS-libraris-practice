# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("dm_office_sales.csv")

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
sns.scatterplot(x='salary', y='sales', data=df,style="division",hue='division')
plt.savefig('myfourthplot.png')

# %%
sns.rugplot(x='salary',data=df,height=0.5)
# Out:
# <Axes: xlabel='salary'>

# %%
sns.set(style='darkgrid')
sns.displot(data=df,x='salary',bins=10,edgecolor='black',ls='--')
# Out:
# C:\Users\THINKPAD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df,x='salary',kde=True, rug=True)
# Out:
# C:\Users\THINKPAD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(data=df,x='salary',kde=True)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.kdeplot(data=df,x='salary')
# Out:
# <Axes: xlabel='salary', ylabel='Density'>

# %%
np.random.seed(42)
sample_ages = np.random.randint(0,100,200)

# %%
sample_ages = pd.DataFrame(data=sample_ages,columns=['age'])

# %%
sample_ages
# Out:
#      age
# 0     51
# 1     92
# 2     14
# 3     71
# 4     60
# ..   ...
# 195   76
# 196    2
# 197   69
# 198   71
# 199   26
#
# [200 rows x 1 columns]

# %%
sns.rugplot(data=sample_ages,x='age')
# Out:
# <Axes: xlabel='age'>

# %%
sns.displot(data=sample_ages,x="age",rug=True,bins=30,kde=True)
# Out:
# C:\Users\THINKPAD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Categorical Plots

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
plt.figure(dpi=200)
sns.countplot(data=df,x='division')
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(dpi=200)
sns.countplot(data=df,x='level of education', hue='division')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6),dpi=300)
sns.barplot(data=df,x='level of education',y='salary',
           estimator=np.mean, errorbar='sd',hue='division')

plt.legend(bbox_to_anchor=(0.25,1.3))

# %% [markdown]
# # Categorical Plots - Distribution within Categories

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.boxplot(y='parental level of education',x='math score',data=df)
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %%
plt.xticks(rotation=90)
sns.boxplot(x='parental level of education',y='math score',data=df,hue='gender')
plt.legend(bbox_to_anchor = (1.05,0.7))

# %%
sns.boxplot(x='math score',y='parental level of education',data=df)
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %%
plt.xticks(rotation=90)
sns.boxplot(x='parental level of education',y='math score',data=df,hue='gender',width=0.3)
plt.legend(bbox_to_anchor = (1.05,0.7))

# %%
plt.xticks(rotation=90)
sns.violinplot(x='parental level of education',y='math score',data=df)
# Out:
# <Axes: xlabel='parental level of education', ylabel='math score'>

# %%
plt.xticks(rotation=90)
sns.violinplot(x='parental level of education', y='math score',data=df,hue='gender')
plt.legend(bbox_to_anchor=(1.05,0.6))

# %%
plt.xticks(rotation=90)
sns.violinplot(x='parental level of education', y='math score',
               data=df, hue='gender', split=True)
plt.legend(bbox_to_anchor=(1.05,0.6))

# %%
plt.xticks(rotation=90)
sns.violinplot(x='parental level of education', y='math score',
               data=df, inner=None)
# Out:
# <Axes: xlabel='parental level of education', ylabel='math score'>

# %%
plt.xticks(rotation=90)
sns.violinplot(x='parental level of education', y='math score',
               data=df, inner='box')
# Out:
# <Axes: xlabel='parental level of education', ylabel='math score'>

# %%
plt.xticks(rotation=90)
sns.violinplot(x='parental level of education', y='math score',
               data=df, inner='quartile')
# Out:
# <Axes: xlabel='parental level of education', ylabel='math score'>

# %%
plt.xticks(rotation=90)
sns.violinplot(x='parental level of education', y='math score',
               data=df, inner='stick')
# Out:
# <Axes: xlabel='parental level of education', ylabel='math score'>

# %%
sns.violinplot(x='math score',y='parental level of education',data=df)
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %%
sns.violinplot(x='math score',y='parental level of education',
               data=df, bw=0.1)
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.swarmplot(x='math score',data=df,size=2)
# Out:
# <Axes: xlabel='math score'>

# %%
sns.swarmplot(x='math score',y='race/ethnicity',data=df,size=3)
# Out:
# <Axes: xlabel='math score', ylabel='race/ethnicity'>

# %%
sns.swarmplot(y='math score',x='race/ethnicity',
              hue='parental level of education',data=df,
              size=3, dodge=True)
plt.legend(bbox_to_anchor=(1.05,0.5))

# %%
sns.boxenplot(x='math score',y='race/ethnicity',data=df)
# Out:
# <Axes: xlabel='math score', ylabel='race/ethnicity'>

# %%
plt.figure(figsize=(12,6))
sns.boxenplot(x='race/ethnicity',y='math score',data=df,hue='gender')
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='math score'>

# %% [markdown]
# # Comparison Plots with pairplot() and jointplot()

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.jointplot(x='math score',y='reading score',data=df)

# %%
sns.jointplot(x='math score',y='reading score',data=df,kind='hex')

# %%
sns.jointplot(x='math score',y='reading score',data=df,kind='kde')

# %%
sns.pairplot(df)
# Out:
# C:\Users\THINKPAD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(data=df, hue='gender', palette='viridis')
# Out:
# C:\Users\THINKPAD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df,hue='gender',palette='viridis',corner=True)
# Out:
# C:\Users\THINKPAD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df,hue='gender',palette='viridis',corner=True,diag_kind='hist')
# Out:
# C:\Users\THINKPAD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Seaborn Grid

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.catplot(data=df,x='gender',y='math score',kind='box')
# Out:
# C:\Users\THINKPAD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df,x='gender',y='math score',kind='box',
            col='test preparation course')
# Out:
# C:\Users\THINKPAD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df,x='gender',y='math score',kind='box',
            row='lunch',col='test preparation course')
# Out:
# C:\Users\THINKPAD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df)
# Out:
# C:\Users\THINKPAD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.PairGrid(df)
g = g.map_upper(sns.scatterplot)
g = g.map_diag(sns.histplot, color='skyblue')
g = g.map_lower(sns.kdeplot,color='lightblue')

# %%
g = sns.PairGrid(df,hue='gender',palette='plasma')
g = g.map_upper(sns.scatterplot)
g = g.map_diag(sns.histplot, color='skyblue')
g = g.map_lower(sns.kdeplot,color='lightblue')
g = g.add_legend()

# %% [markdown]
# # Matrix plots

# %%
df = pd.read_csv('country_table.csv')

# %%
df
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
# 5                          OCEANIA      16.235           6.788
# 6                            WORLD      17.963           7.601
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11
# 5           78.880                 16.939        12.79
# 6           72.766                 27.492        10.36

# %%
df = df.set_index('Countries')

# %%
sns.heatmap(df)
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.heatmap(df.drop('Life expectancy',axis=1))
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.heatmap(df.drop('Life expectancy',axis=1), linewidths=0.1)
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.heatmap(df.drop('Life expectancy',axis=1),linewidths=0.1,annot=True)
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.heatmap(df.drop('Life expectancy',axis=1),linewidths=0.1,
            annot=True,cmap='viridis')
# Out:
# <Axes: ylabel='Countries'>

# %%
sns.clustermap(df.drop('Life expectancy', axis=1))

# %%
sns.clustermap(df.drop('Life expectancy', axis=1),col_cluster=False)

# %%
sns.clustermap(df.drop('Life expectancy', axis=1),col_cluster=False,figsize=(12,8))

# %%
sns.clustermap(df.drop('Life expectancy', axis=1),col_cluster=False,figsize=(12,8),cbar_pos=(-0.1, .2, .03, .4))
